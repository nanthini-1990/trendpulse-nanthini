# %%
# task1_data_collection.py

import requests
import time
import json
import os
from datetime import datetime

# API URLs
TOP_STORIES_URL = "https://hacker-news.firebaseio.com/v0/topstories.json"
ITEM_URL = "https://hacker-news.firebaseio.com/v0/item/{}.json"

# Header
headers = {"User-Agent": "TrendPulse/1.0"}

# Categories with keywords
categories = {
    "technology": ["ai", "software", "tech", "code", "computer", "data", "cloud", "api", "gpu", "llm"],
    "worldnews": ["war", "government", "country", "president", "election", "climate", "attack", "global"],
    "sports": ["nfl", "nba", "fifa", "sport", "game", "team", "player", "league", "championship"],
    "science": ["research", "study", "space", "physics", "biology", "discovery", "nasa", "genome"],
    "entertainment": ["movie", "film", "music", "netflix", "game", "book", "show", "award", "streaming"]
}

# Fetch top story IDs
def fetch_top_story_ids():
    try:
        response = requests.get(TOP_STORIES_URL, headers=headers)
        response.raise_for_status()
        return response.json()[:500]
    except Exception as e:
        print("Error fetching top stories:", e)
        return []

# Fetch single story
def fetch_story(story_id):
    try:
        url = ITEM_URL.format(story_id)
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error fetching story {story_id}: {e}")
        return None

# Assign category based on keywords
def assign_category(title):
    if not title:
        return None

    title = title.lower()

    for category, keywords in categories.items():
        for keyword in keywords:
            if keyword in title:
                return category
    return None

# Main function
def main():
    story_ids = fetch_top_story_ids()

    collected_data = []
    category_counts = {cat: 0 for cat in categories}

    # Loop category-wise
    for category in categories:
        print(f"\nCollecting {category} stories...")

        for story_id in story_ids:
            # Stop if 25 reached
            if category_counts[category] >= 25:
                break

            story = fetch_story(story_id)

            if not story:
                continue

            title = story.get("title", "")
            assigned_category = assign_category(title)

            # Only take matching category
            if assigned_category == category:
                data = {
                    "post_id": story.get("id"),
                    "title": title,
                    "category": category,
                    "score": story.get("score", 0),
                    "num_comments": story.get("descendants", 0),
                    "author": story.get("by", "unknown"),
                    "collected_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                }

                collected_data.append(data)
                category_counts[category] += 1

                print(f"{category_counts[category]} collected for {category}")

        # Sleep after each category
        time.sleep(2)

    # Create data folder
    if not os.path.exists("data"):
        os.makedirs("data")

    # File name
    file_name = f"data/trends_{datetime.now().strftime('%Y%m%d')}.json"

    # Save JSON
    with open(file_name, "w") as file:
        json.dump(collected_data, file, indent=4)

    print("\n✅ Completed!")
    print(f"Total records: {len(collected_data)}")
    print(f"Saved to: {file_name}")


# Run script
if __name__ == "__main__":
    main()
# Out:
# Collecting technology stories...
# 1 collected for technology
# 2 collected for technology
# 3 collected for technology
# 4 collected for technology
# 5 collected for technology
# 6 collected for technology
# 7 collected for technology
# 8 collected for technology
# 9 collected for technology
# 10 collected for technology
# 11 collected for technology
# 12 collected for technology
# 13 collected for technology
# 14 collected for technology
# 15 collected for technology
# 16 collected for technology
# 17 collected for technology
# 18 collected for technology
# 19 collected for technology
# 20 collected for technology
# 21 collected for technology
# 22 collected for technology
# 23 collected for technology
# 24 collected for technology
# 25 collected for technology
#
# Collecting worldnews stories...
# 1 collected for worldnews
# 2 collected for worldnews
# 3 collected for worldnews
# 4 collected for worldnews
# 5 collected for worldnews
# 6 collected for worldnews
# 7 collected for worldnews
# 8 collected for worldnews
# 9 collected for worldnews
# 10 collected for worldnews
# 11 collected for worldnews
# 12 collected for worldnews
# 13 collected for worldnews
# 14 collected for worldnews
# 15 collected for worldnews
# 16 collected for worldnews
# 17 collected for worldnews
# 18 collected for worldnews
# 19 collected for worldnews
# 20 collected for worldnews
# 21 collected for worldnews
#
# Collecting sports stories...
# 1 collected for sports
# 2 collected for sports
# 3 collected for sports
# 4 collected for sports
# 5 collected for sports
# 6 collected for sports
# 7 collected for sports
# 8 collected for sports
# 9 collected for sports
# 10 collected for sports
# 11 collected for sports
# 12 collected for sports
# 13 collected for sports
# 14 collected for sports
#
# Collecting science stories...
# 1 collected for science
# 2 collected for science
# 3 collected for science
# 4 collected for science
# 5 collected for science
# 6 collected for science
# 7 collected for science
#
# Collecting entertainment stories...
# 1 collected for entertainment
# 2 collected for entertainment
# 3 collected for entertainment
# 4 collected for entertainment
# 5 collected for entertainment
# 6 collected for entertainment
# 7 collected for entertainment
# 8 collected for entertainment
# 9 collected for entertainment
# 10 collected for entertainment
# 11 collected for entertainment
# 12 collected for entertainment
# 13 collected for entertainment
# 14 collected for entertainment
# 15 collected for entertainment
# 16 collected for entertainment
# 17 collected for entertainment
# 18 collected for entertainment
# 19 collected for entertainment
# 20 collected for entertainment
# 21 collected for entertainment
# 22 collected for entertainment
# 23 collected for entertainment
# 24 collected for entertainment
# 25 collected for entertainment
#
# ✅ Completed!
# Total records: 92
# Saved to: data/trends_20260408.json
